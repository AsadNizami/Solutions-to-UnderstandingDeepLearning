# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model.to(DEVICE) ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32')).to(DEVICE)
  y_train = torch.tensor(data['y'].transpose().astype('long')).to(DEVICE)
  x_test= torch.tensor(data['x_test'].astype('float32')).to(DEVICE)
  y_test = torch.tensor(data['y_test'].astype('long')).to(DEVICE)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.307333, train error 89.25,  test loss 2.312917, test error 90.30
# Epoch   100, train loss 1.902449, train error 70.22,  test loss 1.758770, test error 68.57
# Epoch   200, train loss 1.869066, train error 70.38,  test loss 1.703701, test error 68.52
# Epoch   300, train loss 1.861283, train error 70.70,  test loss 1.714296, test error 67.68
# Epoch   400, train loss 1.856977, train error 70.10,  test loss 1.684415, test error 66.75
# Epoch   500, train loss 1.853780, train error 70.57,  test loss 1.696013, test error 67.40
# Epoch   600, train loss 1.853861, train error 69.72,  test loss 1.691838, test error 67.12
# Epoch   700, train loss 1.861727, train error 70.57,  test loss 1.700837, test error 68.10
# Epoch   800, train loss 1.855710, train error 69.93,  test loss 1.683336, test error 66.45
# Epoch   900, train loss 1.850668, train error 70.02,  test loss 1.672780, test error 66.65
# Training model with   4 hidden variables
# Epoch     0, train loss 2.293911, train error 86.07,  test loss 2.287852, test error 85.32
# Epoch   100, train loss 1.738335, train error 62.82,  test loss 1.544506, test error 61.45
# Epoch   200, train loss 1.718442, train error 62.15,  test loss 1.516702, test error 58.67
# Epoch   300, train loss 1.714802, train error 62.45,  test loss 1.523040, test error 60.10
# Epoch   400, train loss 1.708330, train error 62.52,  test loss 1.511019, test error 58.85
# Epoch   500, train loss 1.711613, train error 62.57,  test loss 1.525581, test error 60.38
# Epoch   600, train loss 1.700196, train error 61.52,  test loss 1.508298, test error 59.17
# Epoch   700, train loss 1.697678, train error 60.95,  test loss 1.497782, test error 57.75
# Epoch   800, train loss 1.705642, train error 62.88,  test loss 1.514079, test error 59.60
# Epoch   900, train loss 1.695326, train error 62.02,  test loss 1.498458, test error 58.12
# Training model with   6 hidden variables
# Epoch     0, train loss 2.231629, train error 84.65,  test loss 2.211369, test error 83.72
# Epoch   100, train loss 1.616853, train error 56.37,  test loss 1.432295, test error 54.30
# Epoch   200, train loss 1.607096, train error 56.37,  test loss 1.414106, test error 53.82
# Epoch   300, train loss 1.600390, train error 55.95,  test loss 1.409298, test error 53.87
# Epoch   400, train loss 1.600533, train error 55.65,  test loss 1.410386, test error 53.90
# Epoch   500, train loss 1.597603, train error 55.75,  test loss 1.409887, test error 53.70
# Epoch   600, train loss 1.603816, train error 56.02,  test loss 1.406452, test error 54.12
# Epoch   700, train loss 1.597914, train error 55.97,  test loss 1.413654, test error 53.87
# Epoch   800, train loss 1.596195, train error 55.12,  test loss 1.410716, test error 53.32
# Epoch   900, train loss 1.595588, train error 55.40,  test loss 1.404530, test error 53.35
# Training model with   8 hidden variables
# Epoch     0, train loss 2.296383, train error 88.43,  test loss 2.303674, test error 89.05
# Epoch   100, train loss 1.598395, train error 55.50,  test loss 1.424596, test error 53.05
# Epoch   200, train loss 1.538625, train error 53.62,  test loss 1.378294, test error 52.55
# Epoch   300, train loss 1.494610, train error 52.00,  test loss 1.338452, test error 50.55
# Epoch   400, train loss 1.484497, train error 51.77,  test loss 1.341118, test error 51.27
# Epoch   500, train loss 1.475013, train error 51.00,  test loss 1.344221, test error 50.37
# Epoch   600, train loss 1.462867, train error 50.80,  test loss 1.334114, test error 50.52
# Epoch   700, train loss 1.456512, train error 50.00,  test loss 1.324958, test error 49.70
# Epoch   800, train loss 1.459911, train error 50.02,  test loss 1.336447, test error 50.20
# Epoch   900, train loss 1.453717, train error 49.67,  test loss 1.337366, test error 50.12
# Training model with  10 hidden variables
# Epoch     0, train loss 2.246141, train error 82.60,  test loss 2.242671, test error 81.57
# Epoch   100, train loss 1.477265, train error 50.17,  test loss 1.308022, test error 48.50
# Epoch   200, train loss 1.424901, train error 48.87,  test loss 1.296196, test error 48.15
# Epoch   300, train loss 1.413492, train error 47.95,  test loss 1.302633, test error 48.30
# Epoch   400, train loss 1.404082, train error 47.75,  test loss 1.306173, test error 48.42
# Epoch   500, train loss 1.391616, train error 47.22,  test loss 1.299693, test error 47.90
# Epoch   600, train loss 1.386059, train error 46.70,  test loss 1.325312, test error 48.55
# Epoch   700, train loss 1.381423, train error 47.07,  test loss 1.308401, test error 48.17
# Epoch   800, train loss 1.379397, train error 46.32,  test loss 1.331174, test error 48.52
# Epoch   900, train loss 1.375712, train error 46.30,  test loss 1.325585, test error 48.30
# Training model with  14 hidden variables
# Epoch     0, train loss 2.227301, train error 81.93,  test loss 2.207640, test error 81.43
# Epoch   100, train loss 1.483940, train error 51.02,  test loss 1.445504, test error 55.62
# Epoch   200, train loss 1.399494, train error 48.55,  test loss 1.410241, test error 52.02
# Epoch   300, train loss 1.345785, train error 46.12,  test loss 1.391721, test error 50.72
# Epoch   400, train loss 1.319559, train error 45.50,  test loss 1.384559, test error 50.15
# Epoch   500, train loss 1.298677, train error 44.02,  test loss 1.391044, test error 50.42
# Epoch   600, train loss 1.284551, train error 44.15,  test loss 1.399043, test error 50.95
# Epoch   700, train loss 1.279154, train error 43.62,  test loss 1.422057, test error 51.35
# Epoch   800, train loss 1.279535, train error 43.50,  test loss 1.419573, test error 50.80
# Epoch   900, train loss 1.277689, train error 44.32,  test loss 1.421126, test error 51.10
# Training model with  18 hidden variables
# Epoch     0, train loss 2.181515, train error 80.50,  test loss 2.148074, test error 80.25
# Epoch   100, train loss 1.408458, train error 48.15,  test loss 1.387875, test error 51.55
# Epoch   200, train loss 1.287195, train error 43.75,  test loss 1.346850, test error 50.15
# Epoch   300, train loss 1.237395, train error 41.97,  test loss 1.374698, test error 50.12
# Epoch   400, train loss 1.205095, train error 40.42,  test loss 1.379873, test error 49.77
# Epoch   500, train loss 1.205314, train error 42.30,  test loss 1.412712, test error 50.37
# Epoch   600, train loss 1.178118, train error 40.32,  test loss 1.440504, test error 51.20
# Epoch   700, train loss 1.159972, train error 39.17,  test loss 1.438982, test error 51.25
# Epoch   800, train loss 1.154540, train error 39.15,  test loss 1.460803, test error 50.77
# Epoch   900, train loss 1.155487, train error 39.40,  test loss 1.509167, test error 52.35
# Training model with  22 hidden variables
# Epoch     0, train loss 2.219306, train error 83.55,  test loss 2.208609, test error 82.03
# Epoch   100, train loss 1.251215, train error 41.05,  test loss 1.317673, test error 49.22
# Epoch   200, train loss 1.129397, train error 37.27,  test loss 1.368441, test error 48.62
# Epoch   300, train loss 1.074002, train error 35.35,  test loss 1.457329, test error 49.95
# Epoch   400, train loss 1.043937, train error 34.07,  test loss 1.548655, test error 51.22
# Epoch   500, train loss 1.016961, train error 33.57,  test loss 1.587515, test error 51.22
# Epoch   600, train loss 1.022188, train error 35.02,  test loss 1.652557, test error 51.60
# Epoch   700, train loss 0.989383, train error 33.10,  test loss 1.659599, test error 51.80
# Epoch   800, train loss 0.979698, train error 33.12,  test loss 1.703917, test error 51.72
# Epoch   900, train loss 0.979127, train error 32.82,  test loss 1.734631, test error 51.92
# Training model with  26 hidden variables
# Epoch     0, train loss 2.118677, train error 80.12,  test loss 2.083001, test error 79.47
# Epoch   100, train loss 1.235027, train error 42.05,  test loss 1.420865, test error 52.67
# Epoch   200, train loss 1.067941, train error 36.07,  test loss 1.536212, test error 52.80
# Epoch   300, train loss 0.998204, train error 33.52,  test loss 1.651441, test error 52.55
# Epoch   400, train loss 0.945762, train error 31.62,  test loss 1.761881, test error 53.20
# Epoch   500, train loss 0.941572, train error 31.67,  test loss 1.875957, test error 52.80
# Epoch   600, train loss 0.890276, train error 29.30,  test loss 1.963339, test error 53.57
# Epoch   700, train loss 0.880912, train error 29.35,  test loss 2.095548, test error 54.07
# Epoch   800, train loss 0.859549, train error 29.12,  test loss 2.178034, test error 54.60
# Epoch   900, train loss 0.857701, train error 29.40,  test loss 2.256411, test error 55.52
# Training model with  30 hidden variables
# Epoch     0, train loss 2.125660, train error 79.53,  test loss 2.088996, test error 78.40
# Epoch   100, train loss 1.132691, train error 37.95,  test loss 1.412598, test error 51.47
# Epoch   200, train loss 0.954801, train error 31.85,  test loss 1.577025, test error 52.07
# Epoch   300, train loss 0.865123, train error 28.95,  test loss 1.773753, test error 53.92
# Epoch   400, train loss 0.797495, train error 27.32,  test loss 1.944007, test error 53.52
# Epoch   500, train loss 0.771544, train error 26.65,  test loss 2.106430, test error 55.70
# Epoch   600, train loss 0.742781, train error 25.88,  test loss 2.261289, test error 55.32
# Epoch   700, train loss 0.734498, train error 25.45,  test loss 2.382530, test error 55.52
# Epoch   800, train loss 0.708065, train error 24.70,  test loss 2.502942, test error 55.52
# Epoch   900, train loss 0.667961, train error 22.80,  test loss 2.638539, test error 56.65
# Training model with  35 hidden variables
# Epoch     0, train loss 2.169012, train error 80.78,  test loss 2.160702, test error 80.65
# Epoch   100, train loss 1.000537, train error 33.00,  test loss 1.417043, test error 50.20
# Epoch   200, train loss 0.762244, train error 25.88,  test loss 1.745916, test error 52.30
# Epoch   300, train loss 0.660522, train error 22.47,  test loss 2.127823, test error 53.60
# Epoch   400, train loss 0.581479, train error 19.67,  test loss 2.494791, test error 54.47
# Epoch   500, train loss 0.546631, train error 18.60,  test loss 2.838945, test error 54.60
# Epoch   600, train loss 0.510269, train error 17.95,  test loss 3.182929, test error 55.82
# Epoch   700, train loss 0.499767, train error 16.92,  test loss 3.472188, test error 55.82
# Epoch   800, train loss 0.464608, train error 16.02,  test loss 3.802409, test error 56.42
# Epoch   900, train loss 0.428287, train error 15.27,  test loss 4.070253, test error 55.40
# Training model with  40 hidden variables
# Epoch     0, train loss 2.119038, train error 78.32,  test loss 2.076481, test error 78.55
# Epoch   100, train loss 0.925666, train error 29.65,  test loss 1.436749, test error 49.52
# Epoch   200, train loss 0.661949, train error 22.17,  test loss 1.912821, test error 51.92
# Epoch   300, train loss 0.496918, train error 15.75,  test loss 2.526581, test error 53.57
# Epoch   400, train loss 0.404785, train error 13.27,  test loss 3.159662, test error 54.77
# Epoch   500, train loss 0.346065, train error 11.82,  test loss 3.769263, test error 54.82
# Epoch   600, train loss 0.316758, train error 10.82,  test loss 4.452293, test error 56.40
# Epoch   700, train loss 0.319953, train error 11.20,  test loss 5.183935, test error 56.57
# Epoch   800, train loss 0.271441, train error 8.95,  test loss 5.855389, test error 57.17
# Epoch   900, train loss 0.238583, train error 8.12,  test loss 6.552870, test error 57.32
# Training model with  45 hidden variables
# Epoch     0, train loss 2.115346, train error 77.75,  test loss 2.090689, test error 77.93
# Epoch   100, train loss 0.818889, train error 25.40,  test loss 1.542435, test error 50.97
# Epoch   200, train loss 0.506110, train error 16.00,  test loss 2.321373, test error 54.95
# Epoch   300, train loss 0.325420, train error 10.80,  test loss 3.415635, test error 55.77
# Epoch   400, train loss 0.229070, train error 6.82,  test loss 4.664789, test error 57.50
# Epoch   500, train loss 0.153511, train error 4.57,  test loss 5.921996, test error 57.00
# Epoch   600, train loss 0.139489, train error 4.40,  test loss 7.301911, test error 57.50
# Epoch   700, train loss 0.016735, train error -0.00,  test loss 8.450654, test error 57.40
# Epoch   800, train loss 0.010374, train error -0.00,  test loss 9.218864, test error 57.55
# Epoch   900, train loss 0.007637, train error -0.00,  test loss 9.795106, test error 57.52
# Training model with  50 hidden variables
# Epoch     0, train loss 2.083981, train error 77.82,  test loss 2.037483, test error 78.75
# Epoch   100, train loss 0.683139, train error 21.67,  test loss 1.654442, test error 51.92
# Epoch   200, train loss 0.322023, train error 9.80,  test loss 2.815125, test error 54.80
# Epoch   300, train loss 0.122750, train error 2.77,  test loss 4.462195, test error 56.07
# Epoch   400, train loss 0.023321, train error -0.00,  test loss 6.035673, test error 56.22
# Epoch   500, train loss 0.011289, train error -0.00,  test loss 6.890291, test error 56.32
# Epoch   600, train loss 0.007398, train error -0.00,  test loss 7.505090, test error 56.42
# Epoch   700, train loss 0.005348, train error -0.00,  test loss 7.940680, test error 56.47
# Epoch   800, train loss 0.004192, train error -0.00,  test loss 8.296008, test error 56.50
# Epoch   900, train loss 0.003416, train error -0.00,  test loss 8.598999, test error 56.62
# Training model with  55 hidden variables
# Epoch     0, train loss 2.068084, train error 76.93,  test loss 1.999509, test error 75.75
# Epoch   100, train loss 0.619469, train error 19.20,  test loss 1.645572, test error 50.70
# Epoch   200, train loss 0.184580, train error 3.80,  test loss 3.012167, test error 53.82
# Epoch   300, train loss 0.035897, train error 0.02,  test loss 4.738803, test error 54.80
# Epoch   400, train loss 0.013166, train error -0.00,  test loss 5.671812, test error 54.60
# Epoch   500, train loss 0.007860, train error -0.00,  test loss 6.267187, test error 54.95
# Epoch   600, train loss 0.005505, train error -0.00,  test loss 6.693477, test error 55.07
# Epoch   700, train loss 0.004116, train error -0.00,  test loss 7.025576, test error 55.32
# Epoch   800, train loss 0.003269, train error -0.00,  test loss 7.295445, test error 55.52
# Epoch   900, train loss 0.002684, train error -0.00,  test loss 7.518037, test error 55.37
# Training model with  60 hidden variables
# Epoch     0, train loss 2.041052, train error 75.78,  test loss 1.988550, test error 75.60
# Epoch   100, train loss 0.552167, train error 16.45,  test loss 1.731647, test error 50.87
# Epoch   200, train loss 0.104621, train error 1.05,  test loss 3.460050, test error 55.72
# Epoch   300, train loss 0.019824, train error -0.00,  test loss 4.835103, test error 56.12
# Epoch   400, train loss 0.009546, train error -0.00,  test loss 5.535593, test error 56.00
# Epoch   500, train loss 0.005979, train error -0.00,  test loss 5.988156, test error 56.12
# Epoch   600, train loss 0.004283, train error -0.00,  test loss 6.329071, test error 56.20
# Epoch   700, train loss 0.003294, train error -0.00,  test loss 6.599185, test error 56.30
# Epoch   800, train loss 0.002644, train error -0.00,  test loss 6.820645, test error 56.37
# Epoch   900, train loss 0.002196, train error -0.00,  test loss 7.010713, test error 56.40
# Training model with  70 hidden variables
# Epoch     0, train loss 2.051657, train error 77.07,  test loss 1.990390, test error 76.12
# Epoch   100, train loss 0.355547, train error 8.32,  test loss 1.863636, test error 50.80
# Epoch   200, train loss 0.031479, train error -0.00,  test loss 3.396044, test error 51.52
# Epoch   300, train loss 0.010766, train error -0.00,  test loss 4.123949, test error 51.95
# Epoch   400, train loss 0.006093, train error -0.00,  test loss 4.539566, test error 51.82
# Epoch   500, train loss 0.004089, train error -0.00,  test loss 4.825365, test error 51.95
# Epoch   600, train loss 0.003024, train error -0.00,  test loss 5.043714, test error 52.02
# Epoch   700, train loss 0.002379, train error -0.00,  test loss 5.217329, test error 52.00
# Epoch   800, train loss 0.001947, train error -0.00,  test loss 5.364542, test error 52.07
# Epoch   900, train loss 0.001637, train error -0.00,  test loss 5.490657, test error 52.05
# Training model with  80 hidden variables
# Epoch     0, train loss 2.070289, train error 77.18,  test loss 2.023666, test error 76.15
# Epoch   100, train loss 0.259352, train error 5.27,  test loss 2.116632, test error 53.50
# Epoch   200, train loss 0.020438, train error -0.00,  test loss 3.427159, test error 53.05
# Epoch   300, train loss 0.008096, train error -0.00,  test loss 3.990516, test error 53.50
# Epoch   400, train loss 0.004746, train error -0.00,  test loss 4.323624, test error 53.42
# Epoch   500, train loss 0.003276, train error -0.00,  test loss 4.559474, test error 53.15
# Epoch   600, train loss 0.002463, train error -0.00,  test loss 4.744221, test error 53.02
# Epoch   700, train loss 0.001952, train error -0.00,  test loss 4.893327, test error 53.12
# Epoch   800, train loss 0.001606, train error -0.00,  test loss 5.019472, test error 53.20
# Epoch   900, train loss 0.001359, train error -0.00,  test loss 5.129338, test error 53.22
# Training model with  90 hidden variables
# Epoch     0, train loss 2.007495, train error 75.10,  test loss 1.960796, test error 75.60
# Epoch   100, train loss 0.110750, train error 0.37,  test loss 2.207130, test error 51.60
# Epoch   200, train loss 0.013594, train error -0.00,  test loss 3.180976, test error 51.60
# Epoch   300, train loss 0.006159, train error -0.00,  test loss 3.580812, test error 51.40
# Epoch   400, train loss 0.003794, train error -0.00,  test loss 3.831642, test error 51.40
# Epoch   500, train loss 0.002680, train error -0.00,  test loss 4.013553, test error 51.30
# Epoch   600, train loss 0.002045, train error -0.00,  test loss 4.158052, test error 51.35
# Epoch   700, train loss 0.001639, train error -0.00,  test loss 4.274576, test error 51.37
# Epoch   800, train loss 0.001358, train error -0.00,  test loss 4.374787, test error 51.35
# Epoch   900, train loss 0.001155, train error -0.00,  test loss 4.461871, test error 51.32
# Training model with 100 hidden variables
# Epoch     0, train loss 2.020778, train error 73.93,  test loss 1.981630, test error 75.53
# Epoch   100, train loss 0.089531, train error 0.10,  test loss 2.254409, test error 51.55
# Epoch   200, train loss 0.012357, train error -0.00,  test loss 3.136764, test error 51.65
# Epoch   300, train loss 0.005774, train error -0.00,  test loss 3.500296, test error 51.52
# Epoch   400, train loss 0.003609, train error -0.00,  test loss 3.735669, test error 51.47
# Epoch   500, train loss 0.002565, train error -0.00,  test loss 3.906777, test error 51.70
# Epoch   600, train loss 0.001964, train error -0.00,  test loss 4.038348, test error 51.72
# Epoch   700, train loss 0.001579, train error -0.00,  test loss 4.148496, test error 51.80
# Epoch   800, train loss 0.001312, train error -0.00,  test loss 4.241218, test error 51.82
# Epoch   900, train loss 0.001117, train error -0.00,  test loss 4.321397, test error 51.95
# Training model with 120 hidden variables
# Epoch     0, train loss 1.984800, train error 73.50,  test loss 1.904828, test error 73.18
# Epoch   100, train loss 0.048807, train error -0.00,  test loss 2.237756, test error 50.80
# Epoch   200, train loss 0.009468, train error -0.00,  test loss 2.869263, test error 51.10
# Epoch   300, train loss 0.004668, train error -0.00,  test loss 3.143432, test error 51.32
# Epoch   400, train loss 0.002989, train error -0.00,  test loss 3.325078, test error 51.50
# Epoch   500, train loss 0.002153, train error -0.00,  test loss 3.458693, test error 51.42
# Epoch   600, train loss 0.001666, train error -0.00,  test loss 3.563622, test error 51.30
# Epoch   700, train loss 0.001347, train error -0.00,  test loss 3.650851, test error 51.22
# Epoch   800, train loss 0.001125, train error -0.00,  test loss 3.724474, test error 51.22
# Epoch   900, train loss 0.000962, train error -0.00,  test loss 3.788820, test error 51.25
# Training model with 140 hidden variables
# Epoch     0, train loss 1.962289, train error 73.32,  test loss 1.890508, test error 72.20
# Epoch   100, train loss 0.035017, train error -0.00,  test loss 2.120354, test error 49.90
# Epoch   200, train loss 0.007931, train error -0.00,  test loss 2.591051, test error 50.00
# Epoch   300, train loss 0.004077, train error -0.00,  test loss 2.812113, test error 50.22
# Epoch   400, train loss 0.002648, train error -0.00,  test loss 2.957552, test error 50.37
# Epoch   500, train loss 0.001929, train error -0.00,  test loss 3.064740, test error 50.37
# Epoch   600, train loss 0.001500, train error -0.00,  test loss 3.150977, test error 50.35
# Epoch   700, train loss 0.001219, train error -0.00,  test loss 3.222564, test error 50.47
# Epoch   800, train loss 0.001021, train error -0.00,  test loss 3.284106, test error 50.45
# Epoch   900, train loss 0.000875, train error -0.00,  test loss 3.337174, test error 50.45
# Training model with 160 hidden variables
# Epoch     0, train loss 1.943174, train error 71.65,  test loss 1.888504, test error 73.90
# Epoch   100, train loss 0.028416, train error -0.00,  test loss 2.153425, test error 50.17
# Epoch   200, train loss 0.007084, train error -0.00,  test loss 2.573951, test error 50.22
# Epoch   300, train loss 0.003733, train error -0.00,  test loss 2.781139, test error 50.30
# Epoch   400, train loss 0.002455, train error -0.00,  test loss 2.916345, test error 50.27
# Epoch   500, train loss 0.001797, train error -0.00,  test loss 3.017763, test error 50.17
# Epoch   600, train loss 0.001404, train error -0.00,  test loss 3.099816, test error 50.12
# Epoch   700, train loss 0.001144, train error -0.00,  test loss 3.167997, test error 50.22
# Epoch   800, train loss 0.000960, train error -0.00,  test loss 3.224955, test error 50.40
# Epoch   900, train loss 0.000825, train error -0.00,  test loss 3.275937, test error 50.47
# Training model with 180 hidden variables
# Epoch     0, train loss 1.936602, train error 71.90,  test loss 1.872074, test error 72.62
# Epoch   100, train loss 0.024723, train error -0.00,  test loss 2.050438, test error 49.20
# Epoch   200, train loss 0.006642, train error -0.00,  test loss 2.391792, test error 49.07
# Epoch   300, train loss 0.003535, train error -0.00,  test loss 2.566285, test error 48.95
# Epoch   400, train loss 0.002342, train error -0.00,  test loss 2.682806, test error 49.02
# Epoch   500, train loss 0.001723, train error -0.00,  test loss 2.771640, test error 49.07
# Epoch   600, train loss 0.001349, train error -0.00,  test loss 2.842480, test error 49.00
# Epoch   700, train loss 0.001101, train error -0.00,  test loss 2.901537, test error 49.02
# Epoch   800, train loss 0.000926, train error -0.00,  test loss 2.952276, test error 48.97
# Epoch   900, train loss 0.000796, train error -0.00,  test loss 2.996717, test error 48.92
# Training model with 200 hidden variables
# Epoch     0, train loss 1.931131, train error 70.25,  test loss 1.850514, test error 71.95
# Epoch   100, train loss 0.021270, train error -0.00,  test loss 1.915889, test error 48.50
# Epoch   200, train loss 0.006105, train error -0.00,  test loss 2.214406, test error 48.20
# Epoch   300, train loss 0.003315, train error -0.00,  test loss 2.367439, test error 48.20
# Epoch   400, train loss 0.002213, train error -0.00,  test loss 2.470705, test error 48.22
# Epoch   500, train loss 0.001635, train error -0.00,  test loss 2.549076, test error 48.30
# Epoch   600, train loss 0.001284, train error -0.00,  test loss 2.612298, test error 48.17
# Epoch   700, train loss 0.001050, train error -0.00,  test loss 2.664246, test error 48.17
# Epoch   800, train loss 0.000884, train error -0.00,  test loss 2.709546, test error 48.17
# Epoch   900, train loss 0.000761, train error -0.00,  test loss 2.749002, test error 48.10
# Training model with 250 hidden variables
# Epoch     0, train loss 1.880928, train error 68.18,  test loss 1.826159, test error 70.32
# Epoch   100, train loss 0.016756, train error -0.00,  test loss 1.942215, test error 47.65
# Epoch   200, train loss 0.005267, train error -0.00,  test loss 2.192377, test error 47.90
# Epoch   300, train loss 0.002941, train error -0.00,  test loss 2.328380, test error 48.02
# Epoch   400, train loss 0.001984, train error -0.00,  test loss 2.418812, test error 47.97
# Epoch   500, train loss 0.001477, train error -0.00,  test loss 2.488076, test error 47.90
# Epoch   600, train loss 0.001166, train error -0.00,  test loss 2.544665, test error 47.90
# Epoch   700, train loss 0.000957, train error -0.00,  test loss 2.591707, test error 47.85
# Epoch   800, train loss 0.000809, train error -0.00,  test loss 2.632115, test error 47.92
# Epoch   900, train loss 0.000698, train error -0.00,  test loss 2.667984, test error 47.87
# Training model with 300 hidden variables
# Epoch     0, train loss 1.882443, train error 67.22,  test loss 1.795769, test error 69.40
# Epoch   100, train loss 0.014247, train error -0.00,  test loss 1.868872, test error 47.07
# Epoch   200, train loss 0.004752, train error -0.00,  test loss 2.088919, test error 46.97
# Epoch   300, train loss 0.002695, train error -0.00,  test loss 2.207112, test error 47.00
# Epoch   400, train loss 0.001836, train error -0.00,  test loss 2.287996, test error 47.00
# Epoch   500, train loss 0.001374, train error -0.00,  test loss 2.350220, test error 46.97
# Epoch   600, train loss 0.001088, train error -0.00,  test loss 2.400900, test error 46.95
# Epoch   700, train loss 0.000896, train error -0.00,  test loss 2.443052, test error 46.87
# Epoch   800, train loss 0.000758, train error -0.00,  test loss 2.479594, test error 46.87
# Epoch   900, train loss 0.000655, train error -0.00,  test loss 2.511462, test error 46.77
# Training model with 400 hidden variables
# Epoch     0, train loss 1.836807, train error 65.05,  test loss 1.782641, test error 69.40
# Epoch   100, train loss 0.011419, train error -0.00,  test loss 1.801321, test error 45.52
# Epoch   200, train loss 0.004114, train error -0.00,  test loss 1.981238, test error 45.35
# Epoch   300, train loss 0.002391, train error -0.00,  test loss 2.081330, test error 45.27
# Epoch   400, train loss 0.001650, train error -0.00,  test loss 2.151269, test error 45.25
# Epoch   500, train loss 0.001245, train error -0.00,  test loss 2.205186, test error 45.30
# Epoch   600, train loss 0.000991, train error -0.00,  test loss 2.248652, test error 45.15
# Epoch   700, train loss 0.000820, train error -0.00,  test loss 2.284915, test error 45.15
# Epoch   800, train loss 0.000696, train error -0.00,  test loss 2.316883, test error 45.25
# Epoch   900, train loss 0.000603, train error -0.00,  test loss 2.344889, test error 45.20

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
